# %%
import cv2
import matplotlib.pyplot as plt

# %%
file = r'C:\Users\zezorn\Skola\Data_Scientist\ML\Machine-Learning-Practice\data\3_2.png'
test_image = cv2.imread(file, cv2.IMREAD_GRAYSCALE)

plt.imshow(test_image, cmap='grey')

# %%
img_resized = cv2.resize(test_image, (28,28), interpolation=cv2.INTER_AREA)
plt.imshow(img_resized, cmap='grey')

# %%
img_resized = cv2.bitwise_not(img_resized)
plt.imshow(img_resized, cmap='grey')

# %%
def binarize_image(image_array):
    threshold_value = threshold_otsu(image_array)
    image_bin = image_array > threshold_value
    return image_bin.astype(np.uint8) * 255

# %% [markdown]
# Du måste omvandla först till gråskala, sen till svartvitt, sen eventuellt förstärka strecken, sen skala om till 28x28 och sen centrera.
